# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4571-afk/exercise-3/blob/main/EXERCISE_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#string methods
#!.split
#2.join
#3.strip
#4.upper and lower
#5.replace
#6.find
#7.count

# %%
a=" hello world "
b=a.split()
print(a)
print(b)
x=a.replace("hello","world")
print(x)
c=" ".join(b)
print(c)
d="hello"
print(a.upper())
e="WORLD"
print(e.lower())
f="helloworld"
print(f.count("l"))
print(f.find("o"))
print(a.strip())
# Out:
#  hello world
# ['hello', 'world']
#  world world
# hello world
#  HELLO WORLD
# world
# 3
# 4
# hello world

# %%
#program that counts the no of vowels and consonants in a string
a=str(input())
b=a.lower()
vowels="aeiou"
count_v=0;
count_c=0;
for ch in b:
  if ch.isalpha():
    if ch in vowels:
      count_v+=1
    else:
      count_c+=1
print("the no of vowels",count_v)
print("the no of consonants",count_c)
# Out:
# hello
# the no of vowels 2
# the no of consonants 3

# %%
#program that checks the sub string is in the original string if yes print the index of substring
s1=input("enter a string :")
s2=input("enter a substring :")
if s2 in s1:
  print(s1.find(s2))
else:
  print("not present")
# Out:
# enter a string :hello m
# enter a substring :
# 0

# %%
#program that checks the sub string is in the original string if yes print the index of substring
s1=input("enter a string :")
s2=input("enter a substring :")
if s2 in s1:
  print(s1.count(s2))
else:
  print("not present")
# Out:
# enter a string :jhhbgfhjgfhddjhdjghkjh
# enter a substring :f
# 2

# %%
void sub(a,b)
c=a-b
return c
