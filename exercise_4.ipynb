# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4571-afk/exercise-3/blob/main/exercise_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#indexing
#slicing
#concatenation
#repetation
#memebership operators
#iteration

# %%
L1=[1,2,'g',"hii",45]
L2=[4.5,7,4,2,0,9]
print(L1) #print list elements
print(L1[3]) #print index value
print(L1[1:3]) #slicing
print(L2[: :-1]) #print elements in reverse order
print(L2[:8]) #slicing prints upto the index 8
print(L1[:6]) #slicing prints upto the index 6 from starting
print(L1[0:]) #slicing prints upto the last index
print(L1+L2) #adding two lists
print(L1*3) #repetition
print(L2[0:4:2]) #slicing prints upto the index 4 with difference 2 from starting
print(2 in L1) #checks 2 in l1 or not
print(9 not in L2)
for i in L2:
  print(i,end=" ") #iteration through a list
# Out:
# [1, 2, 'g', 'hii', 45]
# hii
# [2, 'g']
# [9, 0, 2, 4, 7, 4.5]
# [4.5, 7, 4, 2, 0, 9]
# [1, 2, 'g', 'hii', 45]
# [1, 2, 'g', 'hii', 45]
# [1, 2, 'g', 'hii', 45, 4.5, 7, 4, 2, 0, 9]
# [1, 2, 'g', 'hii', 45, 1, 2, 'g', 'hii', 45, 1, 2, 'g', 'hii', 45]
# [4.5, 4]
# True
# False
# 4.5 7 4 2 0 9

# %%
L1=[11,22,33,44,55,66,77]
L2=[3,4,5,6,7,8,9]
print(sum(L1))
print(max(L1))
print(min(L1))
print(sum(L2))
print(max(L2))
# Out:
# 308
# 77
# 11
# 42
# 9

# %%
# list methods
#1.append
 #Insert
 #count
 #pop
# remove
 #index
# sort
 #extend
